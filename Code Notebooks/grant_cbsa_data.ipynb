# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./Data/EHB_ACTIVE_GRANT_FA_AGR.csv')

# %%
# df.head()
# df.columns

# %%
# only keep relevant columns
grant_data = df[['Award Year', 'Total Active Grant Financial Assistance', 'Grantee City', 'State Name', 'Grantee ZIP Code', 'Uniform Data System Grant Program Description', 'Grantee County Name', 'Complete County Name','HRSA Region']]

# %%
grant_data.tail()
# Out:
#        Award Year  Total Active Grant Financial Assistance  Grantee City  \
# 24205        2021                                  85475.0       Oriente
# 24206        2021                                 184000.0  Philadelphia
# 24207        2017                                   5303.0        Tacoma
# 24208        2018                                  96750.0        Tacoma
# 24209        2019                                  96750.0        Tacoma
#
#          State Name Grantee ZIP Code  \
# 24205   Puerto Rico            00917
# 24206  Pennsylvania       19131-2318
# 24207    Washington       98465-1900
# 24208    Washington       98465-1900
# 24209    Washington       98465-1900
#
#            Uniform Data System Grant Program Description Grantee County Name  \
# 24205                                                NaN            San Juan
# 24206  This notice announces the opportunity to apply...        Philadelphia
# 24207  This notice announces the opportunity to apply...              Pierce
# 24208  This notice announces the opportunity to apply...              Pierce
# 24209  This notice announces the opportunity to apply...              Pierce
#
#       Complete County Name HRSA Region
# 24205   San Juan Municipio    Region 2
# 24206  Philadelphia County    Region 3
# 24207        Pierce County   Region 10
# 24208        Pierce County   Region 10
# 24209        Pierce County   Region 10

# %%
#filter for only awards in 2019 
grant_data_2019 = grant_data[grant_data['Award Year'] == 2019]
grant_data_2019 = grant_data_2019.reset_index()

#dropna values 
grant_data_2019 = grant_data_2019.dropna()

# %%
# now we want to get county level data
# go from county to population size and determine funding for large vs small counties

# %%
cbsa = pd.read_csv('./Data/cbsa2fipsxw.csv')
cbsa.head()
# Out:
#    cbsacode  metrodivisioncode  csacode                  cbsatitle  \
# 0       NaN                NaN      NaN                        NaN
# 1   33860.0                NaN      NaN             Montgomery, AL
# 2   19300.0                NaN    380.0  Daphne-Fairhope-Foley, AL
# 3   13820.0                NaN    142.0      Birmingham-Hoover, AL
# 4   13820.0                NaN    142.0      Birmingham-Hoover, AL
#
#   metropolitanmicropolitanstatis metropolitandivisiontitle  \
# 0                            NaN                       NaN
# 1  Metropolitan Statistical Area                       NaN
# 2  Metropolitan Statistical Area                       NaN
# 3  Metropolitan Statistical Area                       NaN
# 4  Metropolitan Statistical Area                       NaN
#
#                           csatitle countycountyequivalent statename  \
# 0                              NaN                    NaN       NaN
# 1                              NaN         Autauga County   Alabama
# 2       Mobile-Daphne-Fairhope, AL         Baldwin County   Alabama
# 3  Birmingham-Hoover-Talladega, AL            Bibb County   Alabama
# 4  Birmingham-Hoover-Talladega, AL          Blount County   Alabama
#
#    fipsstatecode  fipscountycode centraloutlyingcounty
# 0            NaN             NaN                   NaN
# 1            1.0             1.0               Central
# 2            1.0             3.0               Central
# 3            1.0             7.0              Outlying
# 4            1.0             9.0              Outlying

# %%
# get grant assistance per state 
# grants_per_county = grant_data_2019.groupby(by='Complete County Name')['Total Active Grant Financial Assistance'].sum().reset_index()
# grants_per_county.head()

grant_data_2019['Mental Health Assistance'] = grant_data_2019.apply(lambda row: row['Total Active Grant Financial Assistance']\
                                                                               if 'mental health' in row['Uniform Data System Grant Program Description'] else 0, axis =1)

grants_per_county = grant_data_2019.groupby(by=['Complete County Name', 'State Name'])[['Total Active Grant Financial Assistance', 'Mental Health Assistance']].sum().reset_index()
grants_per_county.head()
# Out:
#   Complete County Name State Name  Total Active Grant Financial Assistance  \
# 0      Accomack County   Virginia                                5397224.0
# 1           Ada County      Idaho                                4940351.0
# 2         Adair County   Missouri                                3204629.0
# 3         Adams County   Colorado                                 419040.0
# 4         Adams County      Idaho                                1318355.0
#
#    Mental Health Assistance
# 0                       0.0
# 1                  225000.0
# 2                       0.0
# 3                       0.0
# 4                       0.0

# %%
cbsa_data = cbsa[['countycountyequivalent', 'centraloutlyingcounty', 'statename', 'cbsacode']]

#cbsa_data.head()
# merge total grants and mental health grants
grants_per_county_cbsa = grants_per_county.merge(cbsa_data, how='left', left_on='Complete County Name', right_on='countycountyequivalent')

grants_per_county_cbsa.head()
# Out:
#   Complete County Name State Name  Total Active Grant Financial Assistance  \
# 0      Accomack County   Virginia                                5397224.0
# 1           Ada County      Idaho                                4940351.0
# 2         Adair County   Missouri                                3204629.0
# 3         Adams County   Colorado                                 419040.0
# 4         Adams County   Colorado                                 419040.0
#
#    Mental Health Assistance countycountyequivalent centraloutlyingcounty  \
# 0                       0.0                    NaN                   NaN
# 1                  225000.0             Ada County               Central
# 2                       0.0           Adair County               Central
# 3                       0.0           Adams County               Central
# 4                       0.0           Adams County               Central
#
#   statename  cbsacode
# 0       NaN       NaN
# 1     Idaho   14260.0
# 2  Missouri   28860.0
# 3  Colorado   19740.0
# 4  Illinois   39500.0

# %% [markdown]
# ## Merge CBSA dataset to grants by County

# %%
grants_per_county_cbsa = grants_per_county.merge(cbsa_data, how='inner', left_on=['Complete County Name', 'State Name'], right_on=['countycountyequivalent', 'statename'])


grants_per_county_cbsa['Outlying'] = grants_per_county_cbsa['centraloutlyingcounty'].apply(lambda x: 1 if x =='Outlying' else 0)

grants_per_county_cbsa.tail(10)
# Out:
#     Complete County Name      State Name  \
# 688       Yamhill County          Oregon
# 689         Yates County        New York
# 690       Yavapai County         Arizona
# 691   Yellowstone County         Montana
# 692          Yolo County      California
# 693          York County           Maine
# 694          York County    Pennsylvania
# 695          York County  South Carolina
# 696          Yuba County      California
# 697          Yuma County         Arizona
#
#      Total Active Grant Financial Assistance  Mental Health Assistance  \
# 688                                 424054.0                       0.0
# 689                                 381447.0                       0.0
# 690                                2040025.0                       0.0
# 691                                8628304.0                       0.0
# 692                                5910601.0                  349995.0
# 693                                1223178.0                       0.0
# 694                                3610464.0                       0.0
# 695                                4047019.0                       0.0
# 696                                1299842.0                       0.0
# 697                                6364930.0                       0.0
#
#     countycountyequivalent centraloutlyingcounty       statename  cbsacode  \
# 688         Yamhill County              Outlying          Oregon   38900.0
# 689           Yates County              Outlying        New York   40380.0
# 690         Yavapai County               Central         Arizona   39140.0
# 691     Yellowstone County               Central         Montana   13740.0
# 692            Yolo County              Outlying      California   40900.0
# 693            York County               Central           Maine   38860.0
# 694            York County               Central    Pennsylvania   49620.0
# 695            York County              Outlying  South Carolina   16740.0
# 696            Yuba County               Central      California   49700.0
# 697            Yuma County               Central         Arizona   49740.0
#
#      Outlying
# 688         1
# 689         1
# 690         0
# 691         0
# 692         1
# 693         0
# 694         0
# 695         1
# 696         0
# 697         0

# %%
grants_per_county_cbsa[["Outlying", "Total Active Grant Financial Assistance", 'Mental Health Assistance']].corr()
# Out:
#                                          Outlying  \
# Outlying                                 1.000000
# Total Active Grant Financial Assistance -0.103656
# Mental Health Assistance                -0.033752
#
#                                          Total Active Grant Financial Assistance  \
# Outlying                                                               -0.103656
# Total Active Grant Financial Assistance                                 1.000000
# Mental Health Assistance                                                0.268802
#
#                                          Mental Health Assistance
# Outlying                                                -0.033752
# Total Active Grant Financial Assistance                  0.268802
# Mental Health Assistance                                 1.000000

# %%
sns.boxplot(x = "Outlying", y='Total Active Grant Financial Assistance', data = grants_per_county_cbsa)
plt.title("Population size vs. Mental Health Assitance")
# Out:
# Text(0.5, 1.0, 'Population size vs. Mental Health Assitance')

# %%
outlying = grants_per_county_cbsa[grants_per_county_cbsa['Outlying'] == 1]

central = grants_per_county_cbsa[grants_per_county_cbsa['Outlying'] == 0]

outlying[['Total Active Grant Financial Assistance','Mental Health Assistance']].describe()
# Out:
#        Total Active Grant Financial Assistance  Mental Health Assistance
# count                             8.000000e+01                  80.00000
# mean                              2.346892e+06               23567.65000
# std                               2.477258e+06              119109.28324
# min                               3.881000e+03                   0.00000
# 25%                               4.903568e+05                   0.00000
# 50%                               1.651093e+06                   0.00000
# 75%                               3.308265e+06                   0.00000
# max                               1.205123e+07              725000.00000

# %%
central[['Total Active Grant Financial Assistance','Mental Health Assistance']].describe()
# Out:
#        Total Active Grant Financial Assistance  Mental Health Assistance
# count                             6.180000e+02              6.180000e+02
# mean                              7.088095e+06              4.130471e+04
# std                               1.538849e+07              1.727752e+05
# min                               9.263000e+03              0.000000e+00
# 25%                               1.002022e+06              0.000000e+00
# 50%                               3.002804e+06              0.000000e+00
# 75%                               6.329821e+06              0.000000e+00
# max                               1.540145e+08              2.354011e+06

# %%
sns.boxplot(x = "Outlying", y='Total Active Grant Financial Assistance', data = grants_per_county_cbsa)
plt.title("Population size vs. Total Assitance")
# Out:
# Text(0.5, 1.0, 'Population size vs. Total Assitance')

# %%
# grants_per_county_cbsa.to_csv(r'/Users/chiufengyap/OneDrive - The University of Texas Health Science Center at Houston/DS4A/Project/correlationone_team2/Data/grants_per_county_cbsa.csv', index=False)

# %%
grants_per_county_cbsa.to_csv('./Data/grants_per_county_cbsa.csv', index=False)
