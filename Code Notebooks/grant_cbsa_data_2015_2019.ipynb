# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import seaborn as sns

# %%
df = pd.read_csv('./Data/EHB_ACTIVE_GRANT_FA_AGR.csv')

# %%
# df.head()
# df.columns

# %%
# only keep relevant columns
grant_data = df[['Award Year', 'Total Active Grant Financial Assistance', 'Grantee City', 'State Name', 'Grantee ZIP Code', 'Uniform Data System Grant Program Description', 'Grantee County Name', 'Complete County Name','HRSA Region']]

# %%
grant_data.tail()
# Out:
#        Award Year  Total Active Grant Financial Assistance Grantee City  \
# 24213        2019                                 725000.0     Morehead
# 24214        2021                                  99058.0   Frackville
# 24215        2021                                 500000.0       Tucson
# 24216        2021                                  49529.0     Spearman
# 24217        2021                                9301536.0      Lincoln
#
#          State Name Grantee ZIP Code  \
# 24213      Kentucky       40351-1179
# 24214  Pennsylvania       17931-1719
# 24215       Arizona       85704-3850
# 24216         Texas       79081-3441
# 24217      Nebraska       68508-2529
#
#            Uniform Data System Grant Program Description Grantee County Name  \
# 24213  The Rural Communities Opioid Response Program ...               Rowan
# 24214  This notice announces the opportunity to apply...          Schuylkill
# 24215  The Rural Communities Opioid Response Program ...                Pima
# 24216  This notice announces the opportunity to apply...            Hansford
# 24217  ?The program will provide increased COVID-19 t...           Lancaster
#
#       Complete County Name HRSA Region
# 24213         Rowan County    Region 4
# 24214    Schuylkill County    Region 3
# 24215          Pima County    Region 9
# 24216      Hansford County    Region 6
# 24217     Lancaster County    Region 7

# %%
#filter for only awards in 2019 
grant_data_2015_2019 = grant_data[(grant_data['Award Year'] >= 2015) & (grant_data['Award Year'] <= 2019)]
grant_data_2015_2019 = grant_data_2015_2019.reset_index()

#dropna values 
grant_data_2015_2019 = grant_data_2015_2019.dropna()

# %%
# now we want to get county level data
# go from county to population size and determine funding for large vs small counties

# %%
cbsa = pd.read_csv('./Data/cbsa2fipsxw.csv')
cbsa.head()
# Out:
#    cbsacode  metrodivisioncode  csacode                  cbsatitle  \
# 0       NaN                NaN      NaN                        NaN
# 1   33860.0                NaN      NaN             Montgomery, AL
# 2   19300.0                NaN    380.0  Daphne-Fairhope-Foley, AL
# 3   13820.0                NaN    142.0      Birmingham-Hoover, AL
# 4   13820.0                NaN    142.0      Birmingham-Hoover, AL
#
#   metropolitanmicropolitanstatis metropolitandivisiontitle  \
# 0                            NaN                       NaN
# 1  Metropolitan Statistical Area                       NaN
# 2  Metropolitan Statistical Area                       NaN
# 3  Metropolitan Statistical Area                       NaN
# 4  Metropolitan Statistical Area                       NaN
#
#                           csatitle countycountyequivalent statename  \
# 0                              NaN                    NaN       NaN
# 1                              NaN         Autauga County   Alabama
# 2       Mobile-Daphne-Fairhope, AL         Baldwin County   Alabama
# 3  Birmingham-Hoover-Talladega, AL            Bibb County   Alabama
# 4  Birmingham-Hoover-Talladega, AL          Blount County   Alabama
#
#    fipsstatecode  fipscountycode centraloutlyingcounty
# 0            NaN             NaN                   NaN
# 1            1.0             1.0               Central
# 2            1.0             3.0               Central
# 3            1.0             7.0              Outlying
# 4            1.0             9.0              Outlying

# %%
grant_data_2015_2019.head()
# Out:
#     index  Award Year  Total Active Grant Financial Assistance Grantee City  \
# 3      28        2019                                1000000.0    Asheville
# 4      34        2019                                1000000.0        Dixon
# 10     46        2019                                 281553.0        Tulsa
# 12     60        2018                                 199849.0        Albia
# 13     61        2019                                 199503.0        Albia
#
#         State Name Grantee ZIP Code  \
# 3   North Carolina       28801-4136
# 4         Illinois       61021-3116
# 10        Oklahoma       74107-1886
# 12            Iowa       52531-8793
# 13            Iowa       52531-8793
#
#         Uniform Data System Grant Program Description Grantee County Name  \
# 3   The Rural Communities Opioid Response Program ...            Buncombe
# 4   The Rural Communities Opioid Response Program ...                 Lee
# 10  This notice announces the opportunity to apply...               Tulsa
# 12  This notice announces the opportunity to apply...              Monroe
# 13  This notice announces the opportunity to apply...              Monroe
#
#    Complete County Name HRSA Region
# 3       Buncombe County    Region 4
# 4            Lee County    Region 5
# 10         Tulsa County    Region 6
# 12        Monroe County    Region 7
# 13        Monroe County    Region 7

# %%
# get grant assistance per state 
# grants_per_county = grant_data_2019.groupby(by='Complete County Name')['Total Active Grant Financial Assistance'].sum().reset_index()
# grants_per_county.head()

grant_data_2015_2019['Mental Health Assistance'] = grant_data_2015_2019.apply(lambda row: row['Total Active Grant Financial Assistance']\
                                                                               if 'mental health' in row['Uniform Data System Grant Program Description'] else 0, axis =1)

grants_per_county = grant_data_2015_2019.groupby(by=['Complete County Name', 'State Name','Award Year'])[['Total Active Grant Financial Assistance', 'Mental Health Assistance']].sum().reset_index()
grants_per_county.head()
# Out:
#   Complete County Name State Name  Award Year  \
# 0      Accomack County   Virginia        2017
# 1      Accomack County   Virginia        2018
# 2      Accomack County   Virginia        2019
# 3           Ada County      Idaho        2017
# 4           Ada County      Idaho        2018
#
#    Total Active Grant Financial Assistance  Mental Health Assistance
# 0                                  52817.0                       0.0
# 1                                4973949.0                       0.0
# 2                                5397224.0                       0.0
# 3                                1560323.0                   10000.0
# 4                                3254149.0                  225000.0

# %%
cbsa_data = cbsa[['countycountyequivalent', 'centraloutlyingcounty', 'statename', 'cbsacode','metropolitanmicropolitanstatis']]

#cbsa_data.head()
# merge total grants and mental health grants
grants_per_county_cbsa = grants_per_county.merge(cbsa_data, how='left', left_on=['Complete County Name','State Name'], right_on=['countycountyequivalent','statename'])

grants_per_county_cbsa.head()
# Out:
#   Complete County Name State Name  Award Year  \
# 0      Accomack County   Virginia        2017
# 1      Accomack County   Virginia        2018
# 2      Accomack County   Virginia        2019
# 3           Ada County      Idaho        2017
# 4           Ada County      Idaho        2018
#
#    Total Active Grant Financial Assistance  Mental Health Assistance  \
# 0                                  52817.0                       0.0
# 1                                4973949.0                       0.0
# 2                                5397224.0                       0.0
# 3                                1560323.0                   10000.0
# 4                                3254149.0                  225000.0
#
#   countycountyequivalent centraloutlyingcounty statename  cbsacode  \
# 0                    NaN                   NaN       NaN       NaN
# 1                    NaN                   NaN       NaN       NaN
# 2                    NaN                   NaN       NaN       NaN
# 3             Ada County               Central     Idaho   14260.0
# 4             Ada County               Central     Idaho   14260.0
#
#   metropolitanmicropolitanstatis
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3  Metropolitan Statistical Area
# 4  Metropolitan Statistical Area

# %%
# add PDEN10 Mapper 

grants_per_county_cbsa['PDEN10'] = np.where(grants_per_county_cbsa['metropolitanmicropolitanstatis'] == 'Metropolitan Statistical Area',1,
                                np.where(grants_per_county_cbsa['metropolitanmicropolitanstatis'] == 'Micropolitan Statistical Area',
                                2,3))

# %%
grants_per_county_cbsa.to_csv("./Data/grants_per_county_cbsa.csv",index=False)

# %% [markdown]
# # # @Steph, the grants_per_county_cbsa is the df we want to visualize

# %%
grants_per_county_cbsa = grants_per_county.merge(cbsa_data, how='inner', left_on=['Complete County Name', 'State Name'], right_on=['countycountyequivalent', 'statename'])


grants_per_county_cbsa['Outlying'] = grants_per_county_cbsa['centraloutlyingcounty'].apply(lambda x: 1 if x =='Outlying' else 0)

grants_per_county_cbsa.tail(10)
# Out:
#     Complete County Name      State Name  \
# 701       Yamhill County          Oregon
# 702         Yates County        New York
# 703       Yavapai County         Arizona
# 704   Yellowstone County         Montana
# 705          Yolo County      California
# 706          York County           Maine
# 707          York County    Pennsylvania
# 708          York County  South Carolina
# 709          Yuba County      California
# 710          Yuma County         Arizona
#
#      Total Active Grant Financial Assistance  Mental Health Assistance  \
# 701                                1323089.0                       0.0
# 702                                 381447.0                       0.0
# 703                                4230713.0                       0.0
# 704                                9541555.0                       0.0
# 705                               16361489.0                  699965.0
# 706                                2541013.0                       0.0
# 707                                4298419.0                       0.0
# 708                                4883212.0                       0.0
# 709                                2443802.0                       0.0
# 710                                6683502.0                       0.0
#
#     countycountyequivalent centraloutlyingcounty       statename  cbsacode  \
# 701         Yamhill County              Outlying          Oregon   38900.0
# 702           Yates County              Outlying        New York   40380.0
# 703         Yavapai County               Central         Arizona   39140.0
# 704     Yellowstone County               Central         Montana   13740.0
# 705            Yolo County              Outlying      California   40900.0
# 706            York County               Central           Maine   38860.0
# 707            York County               Central    Pennsylvania   49620.0
# 708            York County              Outlying  South Carolina   16740.0
# 709            Yuba County               Central      California   49700.0
# 710            Yuma County               Central         Arizona   49740.0
#
#      Outlying
# 701         1
# 702         1
# 703         0
# 704         0
# 705         1
# 706         0
# 707         0
# 708         1
# 709         0
# 710         0

# %%
grants_per_county_cbsa[["Outlying", "Total Active Grant Financial Assistance", 'Mental Health Assistance']].corr()
# Out:
#                                          Outlying  \
# Outlying                                 1.000000
# Total Active Grant Financial Assistance -0.084758
# Mental Health Assistance                -0.041312
#
#                                          Total Active Grant Financial Assistance  \
# Outlying                                                               -0.084758
# Total Active Grant Financial Assistance                                 1.000000
# Mental Health Assistance                                                0.302384
#
#                                          Mental Health Assistance
# Outlying                                                -0.041312
# Total Active Grant Financial Assistance                  0.302384
# Mental Health Assistance                                 1.000000

# %%
outlying = grants_per_county_cbsa[grants_per_county_cbsa['Outlying'] == 1]

central = grants_per_county_cbsa[grants_per_county_cbsa['Outlying'] == 0]

outlying[['Total Active Grant Financial Assistance','Mental Health Assistance']].describe()
# Out:
#        Total Active Grant Financial Assistance  Mental Health Assistance
# count                             8.100000e+01                 81.000000
# mean                              3.596739e+06              27597.308642
# std                               4.244325e+06             135599.289789
# min                               3.881000e+03                  0.000000
# 25%                               7.123730e+05                  0.000000
# 50%                               2.221400e+06                  0.000000
# 75%                               5.076103e+06                  0.000000
# max                               2.126549e+07             725000.000000

# %%
central[['Total Active Grant Financial Assistance','Mental Health Assistance']].describe()
# Out:
#        Total Active Grant Financial Assistance  Mental Health Assistance
# count                             6.300000e+02              6.300000e+02
# mean                              1.316710e+07              5.687492e+04
# std                               3.797416e+07              2.342490e+05
# min                               4.360000e+03              0.000000e+00
# 25%                               1.205134e+06              0.000000e+00
# 50%                               4.128082e+06              0.000000e+00
# 75%                               9.863407e+06              0.000000e+00
# max                               4.436216e+08              3.254011e+06

# %%
grants_per_county_cbsa.shape
# Out:
# (711, 9)

# %%
grants_per_county_cbsa.to_csv('./Data/grants_data_cleaned.csv',index=False)
